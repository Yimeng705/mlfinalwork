# %%
import numpy as np
import torch
from scipy.spatial.distance import pdist, squareform
from sklearn.metrics.pairwise import cosine_similarity, rbf_kernel
from sklearn.metrics import mutual_info_score
from scipy.stats import entropy
from sklearn.decomposition import PCA
import os
import csv
from sklearn.metrics import silhouette_score
from sklearn.neighbors import NearestNeighbors

# %%
def load_pretrained_emb_weight(model, dataset):
    path = os.path.join('saved', model, dataset, 'pretrain.pth')
    saved = torch.load(path, map_location='cpu', weights_only=False)
    pretrained_emb_weight = saved['item_embedding.weight']
    return pretrained_emb_weight.detach().numpy()[1:]


def get_emb_all(dataset):
    model_list = ['sasrec', 'adrec', 'diffurec', 'dreamrec']
    emb_list = []
    for model in model_list:
        emb_list.append(load_pretrained_emb_weight(model, dataset))
    emb_list.append(np.random.normal(size=emb_list[0].shape))  # 随机高斯分布
    model_list.append('gaussian')
    print(f"Embedding shape: {emb_list[0].shape}")
    return emb_list, model_list

# %%
def norm(matrix):
    return (matrix - matrix.mean(axis=0)) / (matrix.std(axis=0) + 1e-9)


def compute_embedding_variance(embeddings):
    embeddings = embeddings
    return np.var(embeddings, axis=0)


def compute_cosine_similarity(embeddings):
    embeddings = embeddings
    return cosine_similarity(embeddings)


def compute_mutual_distances(embeddings):
    embeddings = embeddings
    distances = pdist(embeddings, metric='euclidean')
    return squareform(distances)


def compute_singular_value_spectrum(embeddings):
    embeddings = norm(embeddings)  # 标准化
    _, s, _ = np.linalg.svd(embeddings, full_matrices=False)
    return s


def singular_value_entropy(singular_values):
    normalized_s = singular_values / (np.sum(singular_values) + 1e-9)
    return entropy(normalized_s)


def singular_value_variance(singular_values):
    return np.var(singular_values)


def evaluate_singular_value(singular_values):
    return singular_value_entropy(singular_values), singular_value_variance(singular_values)


def isotropy_score(embeddings):
    embeddings = norm(embeddings)  # 标准化
    cov = np.cov(embeddings, rowvar=False)
    eigvals = np.linalg.eigvalsh(cov)
    return np.min(eigvals) / (np.max(eigvals) + 1e-9)


def centered_kernel_alignment(X, Y, gamma=1):
    X = norm(X)  # 标准化
    Y = norm(Y)  # 标准化
    K_X = rbf_kernel(X, gamma=gamma)
    K_Y = rbf_kernel(Y, gamma=gamma)
    K_X_centered = K_X - K_X.mean(axis=0) - K_X.mean(axis=1).reshape(-1, 1) + K_X.mean()
    K_Y_centered = K_Y - K_Y.mean(axis=0) - K_Y.mean(axis=1).reshape(-1, 1) + K_Y.mean()
    return np.trace(np.dot(K_X_centered.T, K_Y_centered)) / (
                np.linalg.norm(K_X_centered) * np.linalg.norm(K_Y_centered))


def kl_to_gaussian(embeddings):
    emb_norm = norm(embeddings)  # 标准化
    cov = np.cov(emb_norm, rowvar=False)
    d = embeddings.shape[1]
    kl = 0.5 * (np.trace(cov) - d - np.log(np.linalg.det(cov) + 1e-9))
    return kl


def mutual_info(embeddings):
    emb_norm = embeddings
    labels = np.arange(embeddings.shape[0])
    pca_proj = PCA(n_components=1).fit_transform(emb_norm).squeeze()
    hist, bin_edges = np.histogram(pca_proj, bins=10)
    bins = np.digitize(pca_proj, bin_edges[:-1])
    mi = mutual_info_score(labels, bins)
    return mi


def covariance_entropy(embeddings):
    emb_norm = embeddings 
    cov = np.cov(emb_norm, rowvar=False)
    eigvals = np.linalg.eigvalsh(cov)
    eigvals = np.maximum(eigvals, 1e-9)
    eigvals /= eigvals.sum()
    return entropy(eigvals)


# 2. 轮廓系数（Silhouette Score）
from sklearn.cluster import KMeans

# 计算轮廓系数（Silhouette Score）
def compute_silhouette_score(embeddings, n_clusters=16):
    """使用KMeans生成标签并计算轮廓系数"""
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    labels = kmeans.fit_predict(embeddings)  # 使用KMeans进行聚类，生成标签
    score = silhouette_score(embeddings, labels)  # 计算轮廓系数
    return score

# %%
import csv
import numpy as np

# List of datasets
datasets = ['baby',	'beauty', 'ml-100k', 'sports', 'toys', 'yelp']

# Collect all results
all_results = []

for dataset in datasets:
    embeddings_list, model_names = get_emb_all(dataset)
    for embeddings, model_name in zip(embeddings_list, model_names):
        print(f"====== Evaluating {model_name} embeddings for dataset {dataset} ======")
        
        # 基础指标
        variances = compute_embedding_variance(embeddings)
        embedding_variance = np.mean(variances)
        
        cos_similarity = compute_cosine_similarity(embeddings)
        cosine_similarity_score = np.mean(cos_similarity)
        
        mutual_distances = compute_mutual_distances(embeddings)
        mutual_distance_mean = np.mean(mutual_distances)
        
        # 奇异值谱指标
        singular_values = compute_singular_value_spectrum(embeddings)
        singular_value_top5 = singular_values[:5]
        
        sv_entropy, sv_variance = evaluate_singular_value(singular_values)
        
        # 空间各向同性
        iso_score = isotropy_score(embeddings)
        
        # 高级指标
        kl_score = kl_to_gaussian(embeddings)
        
        mi_score = mutual_info(embeddings)
        
        cov_entropy = covariance_entropy(embeddings)
        
        # 新添加的指标
        silhouette = compute_silhouette_score(embeddings)
        
        # 输出
        print(f"Embedding Variance: {embedding_variance:.3f}")
        print(f"Cosine Similarity: {cosine_similarity_score:.3f}")
        print(f"Mutual Distance mean: {mutual_distance_mean:.3f}")
        print(f"Top 5 Singular Values: {singular_value_top5}")
        print(f"Singular Value Entropy: {sv_entropy:.3f}, Singular Value Variance: {sv_variance:.3f}")
        print(f"Isotropy Score: {iso_score:.3f}")
        print(f"KL Divergence to Gaussian: {kl_score:.3f}")
        print(f"Mutual Information: {mi_score:.3f}")
        print(f"Covariance Matrix Entropy: {cov_entropy:.3f}")
        print(f"Silhouette Score: {silhouette:.3f}")
        print("________________________________\n")
        
        # 保存每个模型的评估结果
        all_results.append([dataset, model_name, round(embedding_variance, 3), round(cosine_similarity_score, 3), 
                            round(mutual_distance_mean, 3), str(np.round(singular_value_top5, 3)),
                            round(sv_entropy, 3), round(sv_variance, 3), round(iso_score, 3),
                            round(kl_score, 3), round(mi_score, 3), round(cov_entropy, 3), 
                            round(silhouette, 3)])
# Out:
# Embedding shape: (4731, 128)
# ====== Evaluating sasrec embeddings for dataset baby ======
# Embedding Variance: 0.010
# Cosine Similarity: 0.236
# Mutual Distance mean: 1.589
# Top 5 Singular Values: [84.73951 79.89948 79.4387  78.92072 78.59443]
# Singular Value Entropy: 4.848, Singular Value Variance: 38.886
# Isotropy Score: 0.235
# KL Divergence to Gaussian: 1.086
# Mutual Information: 1.829
# Covariance Matrix Entropy: 4.836
# Silhouette Score: 0.006
# ________________________________
#
# ====== Evaluating adrec embeddings for dataset baby ======
# Embedding Variance: 0.006
# Cosine Similarity: 0.051
# Mutual Distance mean: 1.259
# Top 5 Singular Values: [247.87593 163.99637 145.34181 138.3336  130.0571 ]
# Singular Value Entropy: 4.740, Singular Value Variance: 1017.591
# Isotropy Score: 0.016
# KL Divergence to Gaussian: 10.375
# Mutual Information: 1.729
# Covariance Matrix Entropy: 4.330
# Silhouette Score: 0.021
# ________________________________
#
# ====== Evaluating diffurec embeddings for dataset baby ======
# Embedding Variance: 0.252
# Cosine Similarity: 0.002
# Mutual Distance mean: 7.925
# Top 5 Singular Values: [106.31131   90.61787   85.6862    81.52818   81.354614]
# Singular Value Entropy: 4.845, Singular Value Variance: 66.940
# Isotropy Score: 0.131
# KL Divergence to Gaussian: 1.827
# Mutual Information: 1.718
# Covariance Matrix Entropy: 4.816
# Silhouette Score: -0.057
# ________________________________
#
# ====== Evaluating dreamrec embeddings for dataset baby ======
# Embedding Variance: 0.031
# Cosine Similarity: 0.002
# Mutual Distance mean: 2.748
# Top 5 Singular Values: [80.57826  80.08692  79.9065   79.019165 78.74934 ]
# Singular Value Entropy: 4.848, Singular Value Variance: 35.292
# Isotropy Score: 0.513
# KL Divergence to Gaussian: 0.962
# Mutual Information: 0.971
# Covariance Matrix Entropy: 4.833
# Silhouette Score: -0.011
# ________________________________
#
# ====== Evaluating gaussian embeddings for dataset baby ======
# Embedding Variance: 1.002
# Cosine Similarity: 0.000
# Mutual Distance mean: 15.982
# Top 5 Singular Values: [80.01104253 78.95660324 78.8298195  78.52497494 78.40730201]
# Singular Value Entropy: 4.849, Singular Value Variance: 32.158
# Isotropy Score: 0.517
# KL Divergence to Gaussian: 0.876
# Mutual Information: 1.655
# Covariance Matrix Entropy: 4.838
# Silhouette Score: 0.006
# ________________________________
#
# Embedding shape: (6086, 128)
# ====== Evaluating sasrec embeddings for dataset beauty ======
# Embedding Variance: 0.010
# Cosine Similarity: 0.309
# Mutual Distance mean: 1.606
# Top 5 Singular Values: [128.69994  125.13879  106.41139   97.85577   94.196175]
# Singular Value Entropy: 4.844, Singular Value Variance: 101.554
# Isotropy Score: 0.087
# KL Divergence to Gaussian: 2.112
# Mutual Information: 1.632
# Covariance Matrix Entropy: 4.812
# Silhouette Score: 0.008
# ________________________________
#
# ====== Evaluating adrec embeddings for dataset beauty ======
# Embedding Variance: 0.016
# Cosine Similarity: 0.011
# Mutual Distance mean: 2.033
# Top 5 Singular Values: [177.18913  159.3719   145.51747  137.73712  126.746994]
# Singular Value Entropy: 4.756, Singular Value Variance: 995.553
# Isotropy Score: 0.016
# KL Divergence to Gaussian: 10.372
# Mutual Information: 1.729
# Covariance Matrix Entropy: 4.508
# Silhouette Score: 0.021
# ________________________________
#
# ====== Evaluating diffurec embeddings for dataset beauty ======
# Embedding Variance: 0.242
# Cosine Similarity: 0.002
# Mutual Distance mean: 7.764
# Top 5 Singular Values: [129.97845  116.92851  113.326004  97.61187   97.34866 ]
# Singular Value Entropy: 4.843, Singular Value Variance: 108.987
# Isotropy Score: 0.101
# KL Divergence to Gaussian: 2.254
# Mutual Information: 1.653
# Covariance Matrix Entropy: 4.811
# Silhouette Score: -0.047
# ________________________________
#
# ====== Evaluating dreamrec embeddings for dataset beauty ======
# Embedding Variance: 0.098
# Cosine Similarity: 0.001
# Mutual Distance mean: 4.971
# Top 5 Singular Values: [89.69917  88.47673  88.321686 87.74045  87.62439 ]
# Singular Value Entropy: 4.849, Singular Value Variance: 33.162
# Isotropy Score: 0.561
# KL Divergence to Gaussian: 0.701
# Mutual Information: 1.169
# Covariance Matrix Entropy: 4.839
# Silhouette Score: 0.003
# ________________________________
#
# ====== Evaluating gaussian embeddings for dataset beauty ======
# Embedding Variance: 1.001
# Cosine Similarity: 0.000
# Mutual Distance mean: 15.972
# Top 5 Singular Values: [89.09949649 88.84279858 88.05620546 87.94959891 87.60985118]
# Singular Value Entropy: 4.849, Singular Value Variance: 32.289
# Isotropy Score: 0.573
# KL Divergence to Gaussian: 0.683
# Mutual Information: 1.768
# Covariance Matrix Entropy: 4.841
# Silhouette Score: 0.006
# ________________________________
#
# Embedding shape: (1008, 128)
# ====== Evaluating sasrec embeddings for dataset ml-100k ======
# Embedding Variance: 0.010
# Cosine Similarity: 0.185
# Mutual Distance mean: 1.590
# Top 5 Singular Values: [42.3697  42.03066 41.779   41.60197 41.50376]
# Singular Value Entropy: 4.834, Singular Value Variance: 34.326
# Isotropy Score: 0.111
# KL Divergence to Gaussian: 4.601
# Mutual Information: 1.697
# Covariance Matrix Entropy: 4.784
# Silhouette Score: -0.005
# ________________________________
#
# ====== Evaluating adrec embeddings for dataset ml-100k ======
# Embedding Variance: 0.011
# Cosine Similarity: 0.006
# Mutual Distance mean: 1.651
# Top 5 Singular Values: [90.90994  82.49756  71.19577  63.543674 53.67996 ]
# Singular Value Entropy: 4.796, Singular Value Variance: 122.571
# Isotropy Score: 0.036
# KL Divergence to Gaussian: 10.425
# Mutual Information: 2.133
# Covariance Matrix Entropy: 4.547
# Silhouette Score: 0.026
# ________________________________
#
# ====== Evaluating diffurec embeddings for dataset ml-100k ======
# Embedding Variance: 0.600
# Cosine Similarity: 0.002
# Mutual Distance mean: 12.341
# Top 5 Singular Values: [55.41819  49.44244  44.242085 42.54949  41.40837 ]
# Singular Value Entropy: 4.832, Singular Value Variance: 38.747
# Isotropy Score: 0.039
# KL Divergence to Gaussian: 5.151
# Mutual Information: 2.061
# Covariance Matrix Entropy: 4.773
# Silhouette Score: -0.001
# ________________________________
#
# ====== Evaluating dreamrec embeddings for dataset ml-100k ======
# Embedding Variance: 0.822
# Cosine Similarity: 0.001
# Mutual Distance mean: 14.465
# Top 5 Singular Values: [43.157776 42.636543 42.422783 41.825146 41.465584]
# Singular Value Entropy: 4.835, Singular Value Variance: 33.564
# Isotropy Score: 0.226
# KL Divergence to Gaussian: 4.408
# Mutual Information: 1.850
# Covariance Matrix Entropy: 4.784
# Silhouette Score: 0.003
# ________________________________
#
# ====== Evaluating gaussian embeddings for dataset ml-100k ======
# Embedding Variance: 1.000
# Cosine Similarity: 0.001
# Mutual Distance mean: 15.960
# Top 5 Singular Values: [42.20604582 41.90999548 41.64363131 41.49823211 40.99711683]
# Singular Value Entropy: 4.836, Singular Value Variance: 31.631
# Isotropy Score: 0.246
# KL Divergence to Gaussian: 4.161
# Mutual Information: 1.800
# Covariance Matrix Entropy: 4.789
# Silhouette Score: 0.004
# ________________________________
#
# Embedding shape: (12301, 128)
# ====== Evaluating sasrec embeddings for dataset sports ======
# Embedding Variance: 0.010
# Cosine Similarity: 0.248
# Mutual Distance mean: 1.593
# Top 5 Singular Values: [133.9134   125.74086  122.40291  122.00218  120.975204]
# Singular Value Entropy: 4.849, Singular Value Variance: 68.146
# Isotropy Score: 0.133
# KL Divergence to Gaussian: 0.812
# Mutual Information: 1.740
# Covariance Matrix Entropy: 4.842
# Silhouette Score: 0.005
# ________________________________
#
# ====== Evaluating adrec embeddings for dataset sports ======
# Embedding Variance: 0.006
# Cosine Similarity: 0.061
# Mutual Distance mean: 1.242
# Top 5 Singular Values: [415.16367 355.93463 317.39752 275.29926 257.7226 ]
# Singular Value Entropy: 4.645, Singular Value Variance: 4332.995
# Isotropy Score: 0.006
# KL Divergence to Gaussian: 10.367
# Mutual Information: 1.783
# Covariance Matrix Entropy: 3.971
# Silhouette Score: 0.041
# ________________________________
#
# ====== Evaluating diffurec embeddings for dataset sports ======
# Embedding Variance: 0.090
# Cosine Similarity: 0.003
# Mutual Distance mean: 4.705
# Top 5 Singular Values: [220.3282  182.84767 172.72208 151.12769 137.70288]
# Singular Value Entropy: 4.839, Singular Value Variance: 347.808
# Isotropy Score: 0.088
# KL Divergence to Gaussian: 3.431
# Mutual Information: 1.868
# Covariance Matrix Entropy: 4.787
# Silhouette Score: -0.056
# ________________________________
#
# ====== Evaluating dreamrec embeddings for dataset sports ======
# Embedding Variance: 0.035
# Cosine Similarity: 0.000
# Mutual Distance mean: 2.945
# Top 5 Singular Values: [122.181145 121.81259  121.40194  121.03467  120.88172 ]
# Singular Value Entropy: 4.851, Singular Value Variance: 33.161
# Isotropy Score: 0.664
# KL Divergence to Gaussian: 0.346
# Mutual Information: 0.879
# Covariance Matrix Entropy: 4.845
# Silhouette Score: -0.003
# ________________________________
#
# ====== Evaluating gaussian embeddings for dataset sports ======
# Embedding Variance: 1.001
# Cosine Similarity: 0.000
# Mutual Distance mean: 15.974
# Top 5 Singular Values: [121.89329537 121.46971159 121.33387789 120.98539742 120.20669745]
# Singular Value Entropy: 4.851, Singular Value Variance: 31.763
# Isotropy Score: 0.672
# KL Divergence to Gaussian: 0.332
# Mutual Information: 1.724
# Covariance Matrix Entropy: 4.847
# Silhouette Score: 0.005
# ________________________________
#
# Embedding shape: (7309, 128)
# ====== Evaluating sasrec embeddings for dataset toys ======
# Embedding Variance: 0.010
# Cosine Similarity: 0.239
# Mutual Distance mean: 1.589
# Top 5 Singular Values: [103.280014  97.69571   96.77753   96.15351   95.161896]
# Singular Value Entropy: 4.848, Singular Value Variance: 52.630
# Isotropy Score: 0.131
# KL Divergence to Gaussian: 1.029
# Mutual Information: 1.696
# Covariance Matrix Entropy: 4.838
# Silhouette Score: 0.005
# ________________________________
#
# ====== Evaluating adrec embeddings for dataset toys ======
# Embedding Variance: 0.022
# Cosine Similarity: 0.018
# Mutual Distance mean: 2.358
# Top 5 Singular Values: [182.02626 156.39467 148.03304 139.77176 137.68404]
# Singular Value Entropy: 4.747, Singular Value Variance: 1243.761
# Isotropy Score: 0.013
# KL Divergence to Gaussian: 10.370
# Mutual Information: 1.867
# Covariance Matrix Entropy: 4.505
# Silhouette Score: 0.016
# ________________________________
#
# ====== Evaluating diffurec embeddings for dataset toys ======
# Embedding Variance: 0.210
# Cosine Similarity: 0.001
# Mutual Distance mean: 7.265
# Top 5 Singular Values: [139.38164 135.45657 117.64824 106.73915 105.76859]
# Singular Value Entropy: 4.843, Singular Value Variance: 138.120
# Isotropy Score: 0.102
# KL Divergence to Gaussian: 2.387
# Mutual Information: 1.814
# Covariance Matrix Entropy: 4.809
# Silhouette Score: -0.031
# ________________________________
#
# ====== Evaluating dreamrec embeddings for dataset toys ======
# Embedding Variance: 0.027
# Cosine Similarity: 0.001
# Mutual Distance mean: 2.453
# Top 5 Singular Values: [109.574196 107.45628  106.1846   104.876526 103.48446 ]
# Singular Value Entropy: 4.846, Singular Value Variance: 91.018
# Isotropy Score: 0.401
# KL Divergence to Gaussian: 1.591
# Mutual Information: 0.417
# Covariance Matrix Entropy: 4.823
# Silhouette Score: -0.022
# ________________________________
#
# ====== Evaluating gaussian embeddings for dataset toys ======
# Embedding Variance: 1.001
# Cosine Similarity: 0.000
# Mutual Distance mean: 15.979
# Top 5 Singular Values: [96.59198022 96.4653853  95.93543811 95.6102993  95.21887559]
# Singular Value Entropy: 4.850, Singular Value Variance: 32.771
# Isotropy Score: 0.601
# KL Divergence to Gaussian: 0.576
# Mutual Information: 1.807
# Covariance Matrix Entropy: 4.843
# Silhouette Score: 0.006
# ________________________________
#
# Embedding shape: (64669, 128)
# ====== Evaluating sasrec embeddings for dataset yelp ======
# Embedding Variance: 0.004
# Cosine Similarity: 0.032
# Mutual Distance mean: 0.992
# Top 5 Singular Values: [843.7824  675.19836 636.0437  625.64526 568.5741 ]
# Singular Value Entropy: 4.765, Singular Value Variance: 12385.478
# Isotropy Score: 0.028
# KL Divergence to Gaussian: 10.363
# Mutual Information: 1.673
# Covariance Matrix Entropy: 4.304
# Silhouette Score: 0.056
# ________________________________
#
# ====== Evaluating adrec embeddings for dataset yelp ======
# Embedding Variance: 0.006
# Cosine Similarity: 0.004
# Mutual Distance mean: 1.196
# Top 5 Singular Values: [810.28644 781.1778  625.4175  566.8137  541.5048 ]
# Singular Value Entropy: 4.680, Singular Value Variance: 18955.465
# Isotropy Score: 0.006
# KL Divergence to Gaussian: 10.363
# Mutual Information: 1.511
# Covariance Matrix Entropy: 4.123
# Silhouette Score: 0.056
# ________________________________
#
# ====== Evaluating diffurec embeddings for dataset yelp ======
# Embedding Variance: 0.007
# Cosine Similarity: 0.006
# Mutual Distance mean: 1.261
# Top 5 Singular Values: [772.81256 690.31586 623.1696  587.23267 577.2554 ]
# Singular Value Entropy: 4.747, Singular Value Variance: 13798.543
# Isotropy Score: 0.026
# KL Divergence to Gaussian: 10.364
# Mutual Information: 1.653
# Covariance Matrix Entropy: 4.268
# Silhouette Score: 0.039
# ________________________________
#
# ====== Evaluating dreamrec embeddings for dataset yelp ======
# Embedding Variance: 0.009
# Cosine Similarity: 0.000
# Mutual Distance mean: 1.455
# Top 5 Singular Values: [265.58694 265.07474 264.78207 264.30826 264.19104]
# Singular Value Entropy: 4.852, Singular Value Variance: 32.512
# Isotropy Score: 0.840
# KL Divergence to Gaussian: 0.064
# Mutual Information: 0.664
# Covariance Matrix Entropy: 4.850
# Silhouette Score: 0.001
# ________________________________
#
# ====== Evaluating gaussian embeddings for dataset yelp ======
# Embedding Variance: 1.000
# Cosine Similarity: 0.000
# Mutual Distance mean: 15.969
# Top 5 Singular Values: [265.43601741 264.96434382 264.69329556 264.49453367 264.06072028]
# Singular Value Entropy: 4.852, Singular Value Variance: 32.192
# Isotropy Score: 0.839
# KL Divergence to Gaussian: 0.064
# Mutual Information: 1.605
# Covariance Matrix Entropy: 4.851
# Silhouette Score: 0.004
# ________________________________

# %%
def save_results_to_csv(results, filename="embedding_results.csv"):
    # Define header
    header = ["Dataset", "Model", "Embedding Variance", "Cosine Similarity", "Mutual Distance Mean",
              "Top 5 Singular Values", "Singular Value Entropy", "Singular Value Variance",
              "Isotropy Score", "KL Divergence to Gaussian", "Mutual Information", "Covariance Matrix Entropy", "Silhouette Score"]

    # Write results to CSV
    with open(filename, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(header)
        for row in results:
            writer.writerow(row)
    print(f"Results saved to {filename}")

# %%
# 保存结果到CSV文件
# Save results to CSV file
save_results_to_csv(all_results)
# Out:
# Results saved to embedding_results.csv
